# %% [markdown]
# # Analysis on House Price Data

# %%
# import numpy
import numpy as np

# import pandas
import pandas as pd

# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

# %%
# import the dataset
df_House_Price_Data = pd.read_csv("C:\\Users\\Hetvi\\Downloads\\House_Price.csv")

# %%
# show first five observation(rows) the dataset
df_House_Price_Data.head()
# Out:
#    price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 0   24.0     0.00632       32.31     0.538     6.575  65.2   4.35   3.81
# 1   21.6     0.02731       37.07     0.469     6.421  78.9   4.99   4.70
# 2   34.7     0.02729       37.07     0.469     7.185  61.1   5.03   4.86
# 3   33.4     0.03237       32.18     0.458     6.998  45.8   6.21   5.93
# 4   36.2     0.06905       32.18     0.458     7.147  54.2   6.16   5.86
#
#    dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 0   4.18   4.01      24.7       4.98     YES       5.480      11.1920
# 1   5.12   5.06      22.2       9.14      NO       7.332      12.1728
# 2   5.01   4.97      22.2       4.03      NO       7.394     101.1200
# 3   6.16   5.96      21.3       2.94     YES       9.268      11.2672
# 4   6.37   5.86      21.3       5.33      NO       8.824      11.2896
#
#   waterbody  rainfall bus_ter     parks
# 0     River        23     YES  0.049347
# ...

# %%
# show last five observation(rows) the dataset
df_House_Price_Data.tail()
# Out:
#      price  crime_rate  resid_area  air_qual  room_num   age  dist1  dist2  \
# 501   22.4     0.06263       41.93     0.573     6.593  69.1   2.64   2.45
# 502   20.6     0.04527       41.93     0.573     6.120  76.7   2.44   2.11
# 503   23.9     0.06076       41.93     0.573     6.976  91.0   2.34   2.06
# 504   22.0     0.10959       41.93     0.573     6.794  89.3   2.54   2.31
# 505   19.0     0.04741       41.93     0.573     6.030  80.8   2.72   2.24
#
#      dist3  dist4  teachers  poor_prop airport  n_hos_beds  n_hot_rooms  \
# 501   2.76   2.06      19.0       9.67      NO       9.348      12.1792
# 502   2.46   2.14      19.0       9.08     YES       6.612      13.1648
# 503   2.29   1.98      19.0       5.64      NO       5.478      12.1912
# 504   2.40   2.31      19.0       6.48     YES       7.940      15.1760
# 505   2.64   2.42      19.0       7.88     YES      10.280      10.1520
#
#           waterbody  rainfall bus_ter     parks
# ...

# %% [markdown]
# # 1. Data Overview

# %%
# show the attributes(column) names
df_House_Price_Data.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %% [markdown]
# **Column Info**
#  - `price`: Price of the House
#  - `crime_rate`: crime rate in that area
#  - `resid_area`: Residential Area
#  - `air_qual`: Air Quality in that area
#  - `room_num`: Number of Rooms in House
#  - `age`: Average age of people in that area
#  - `dist1`: Distance from Employment Hub 1 to Houses
#  - `dist2`: Distance from Employment Hub2 to Houses
#  - `dist3`: Distance from Employment Hub3 to House
#  - `dist4`: Distance from Employment Hub4 to House
#  - `teachers`: Number of Teachers in that area
#  - `poor_prop`: Proportion of Poor Population in that area
#  - `airport`: Airport is present or not in that area
#  - `n_hos_beds`: Number of Hospital Beds available in that area
#  - `n_hot_rooms`: Number of Hotel Rooms in that area
#  - `waterbody`: Type of waterbody in that area
#  - `rainfall`: Rainfall in that area
#  - `bus_ter`: Bus terminal in that area
#  - `parks`: Number of Parks in that areaks'

# %% [markdown]
# ## Basic statistics(descriptive statistics)

# %%
# Shape of the data
# Basic Info
# Basic Description

# %%
# Shape of the Data
df_House_Price_Data.shape
# Out:
# (506, 19)

# %% [markdown]
# **Interpretetion**
#  - We have 506 observation and 19 attributes

# %%
# Basic Info
df_House_Price_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   price        506 non-null    float64
#  1   crime_rate   506 non-null    float64
#  2   resid_area   506 non-null    float64
#  3   air_qual     506 non-null    float64
#  4   room_num     506 non-null    float64
#  5   age          506 non-null    float64
#  6   dist1        506 non-null    float64
#  7   dist2        506 non-null    float64
#  8   dist3        506 non-null    float64
#  9   dist4        506 non-null    float64
#  10  teachers     506 non-null    float64
#  11  poor_prop    506 non-null    float64
#  12  airport      506 non-null    object
#  13  n_hos_beds   498 non-null    float64
#  14  n_hot_rooms  506 non-null    float64
#  15  waterbody    351 non-null    object
#  16  rainfall     506 non-null    int64
#  17  bus_ter      506 non-null    object
# ...

# %% [markdown]
# **Interpretetion**
#  - We have 16 numerical attributes. It includes 15 floats and 1 integer.
#  - We have 3 Categorical Attributes.
#  - In the data we have valid null values.

# %%
# Basic Description
df_House_Price_Data.describe().T
# Out:
#              count       mean        std        min        25%        50%  \
# price        506.0  22.528854   9.182176   5.000000  17.025000  21.200000
# crime_rate   506.0   3.613524   8.601545   0.006320   0.082045   0.256510
# resid_area   506.0  41.136779   6.860353  30.460000  35.190000  39.690000
# air_qual     506.0   0.554695   0.115878   0.385000   0.449000   0.538000
# room_num     506.0   6.284634   0.702617   3.561000   5.885500   6.208500
# age          506.0  68.574901  28.148861   2.900000  45.025000  77.500000
# dist1        506.0   3.971996   2.108532   1.130000   2.270000   3.385000
# dist2        506.0   3.628775   2.108580   0.920000   1.940000   3.010000
# dist3        506.0   3.960672   2.119797   1.150000   2.232500   3.375000
# dist4        506.0   3.618972   2.099203   0.730000   1.940000   3.070000
# teachers     506.0  21.544466   2.164946  18.000000  19.800000  20.950000
# poor_prop    506.0  12.653063   7.141062   1.730000   6.950000  11.360000
# ...

# %% [markdown]
# **Interpretetion**
#  - We have outliers in `crime_rate` , `resid_area` , `age`

# %% [markdown]
# # 2. Data Pre-processing

# %%
# Data Cleaning
# Null value handling
# Outlier treatment

# %% [markdown]
# ### Data Cleaning

# %%
df_House_Price_Data.columns
# Out:
# Index(['price', 'crime_rate', 'resid_area', 'air_qual', 'room_num', 'age',
#        'dist1', 'dist2', 'dist3', 'dist4', 'teachers', 'poor_prop', 'airport',
#        'n_hos_beds', 'n_hot_rooms', 'waterbody', 'rainfall', 'bus_ter',
#        'parks'],
#       dtype='object')

# %%
# Let`s Rename the columns
df_House_Price_Data= df_House_Price_Data.rename(columns= {'price': 'Price', 'crime_rate': 'Crime_Rate', 'resid_area': 'Resid_Area', 
                                     'air_qual': 'Air_Qualitiy', 'room_num': 'Room_num', 'age': 'Age','dist1':'Dist1', 
                                     'dist2': 'Dist2', 'dist3': 'Dist3', 'dist4': 'Dist4', 'teachers': 'Teachers', 
                                     'poor_prop': 'Poor_Prop', 'airport': 'Airport','n_hos_beds': 'Num_Hos_Beds', 
                                     'n_hot_rooms': 'Num_Hot_Rooms', 'waterbody': 'Waterbody', 'rainfall': 'Rainfall', 
                                     'bus_ter': 'Bus_Ter','parks': 'Parks' })

# %%
df_House_Price_Data
# Out:
#      Price  Crime_Rate  Resid_Area  Air_Qualitiy  Room_num   Age  Dist1  \
# 0     24.0     0.00632       32.31         0.538     6.575  65.2   4.35
# 1     21.6     0.02731       37.07         0.469     6.421  78.9   4.99
# 2     34.7     0.02729       37.07         0.469     7.185  61.1   5.03
# 3     33.4     0.03237       32.18         0.458     6.998  45.8   6.21
# 4     36.2     0.06905       32.18         0.458     7.147  54.2   6.16
# ..     ...         ...         ...           ...       ...   ...    ...
# 501   22.4     0.06263       41.93         0.573     6.593  69.1   2.64
# 502   20.6     0.04527       41.93         0.573     6.120  76.7   2.44
# 503   23.9     0.06076       41.93         0.573     6.976  91.0   2.34
# 504   22.0     0.10959       41.93         0.573     6.794  89.3   2.54
# 505   19.0     0.04741       41.93         0.573     6.030  80.8   2.72
#
#      Dist2  Dist3  Dist4  Teachers  Poor_Prop Airport  Num_Hos_Beds  \
# ...

# %%
# Let`s do this Type Casting here
# Room_num 
# Age
# Teachers
# Num_Hos_Beds
# Num_Hot_Rooms

# %%
df_House_Price_Data['Room_num'] = df_House_Price_Data['Room_num'].astype('int')

# %%
df_House_Price_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          506 non-null    float64
#  1   Crime_Rate     506 non-null    float64
#  2   Resid_Area     506 non-null    float64
#  3   Air_Qualitiy   506 non-null    float64
#  4   Room_num       506 non-null    int32
#  5   Age            506 non-null    float64
#  6   Dist1          506 non-null    float64
#  7   Dist2          506 non-null    float64
#  8   Dist3          506 non-null    float64
#  9   Dist4          506 non-null    float64
#  10  Teachers       506 non-null    float64
#  11  Poor_Prop      506 non-null    float64
#  12  Airport        506 non-null    object
#  13  Num_Hos_Beds   498 non-null    float64
#  14  Num_Hot_Rooms  506 non-null    float64
#  15  Waterbody      351 non-null    object
#  16  Rainfall       506 non-null    int64
# ...

# %%
df_House_Price_Data['Age'] = df_House_Price_Data['Age'].astype('int')

# %%
df_House_Price_Data['Teachers'] = df_House_Price_Data['Teachers'].astype('int')

# %% [raw]
# df_House_Price_Data['Num_Hos_Beds'] = df_House_Price_Data['Num_Hos_Beds'].astype('int')

# %%
df_House_Price_Data['Num_Hot_Rooms'] = df_House_Price_Data['Num_Hot_Rooms'].astype('int')

# %%
# In previous we did the type casting based on observations and domain expertice
# Now the time is for the data visualization
df_House_Price_Data.hist()
plt.tight_layout() 
plt.show()

# %%
df_House_Price_Data.Price.plot(kind = 'kde')
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %%
# Room_num
# Num_Hot_Rooms
df_House_Price_Data.Room_num.hist(color = 'purple')
plt.show()

# %%
df_House_Price_Data.Num_Hot_Rooms.hist(color = 'purple')
plt.show()

# %%
df_House_Price_Data.Num_Hot_Rooms.plot(kind = 'kde')
plt.show()

# %%
df_House_Price_Data['Room_num'] = df_House_Price_Data['Room_num'].astype('object')

# %%
df_House_Price_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          506 non-null    float64
#  1   Crime_Rate     506 non-null    float64
#  2   Resid_Area     506 non-null    float64
#  3   Air_Qualitiy   506 non-null    float64
#  4   Room_num       506 non-null    object
#  5   Age            506 non-null    int32
#  6   Dist1          506 non-null    float64
#  7   Dist2          506 non-null    float64
#  8   Dist3          506 non-null    float64
#  9   Dist4          506 non-null    float64
#  10  Teachers       506 non-null    int32
#  11  Poor_Prop      506 non-null    float64
#  12  Airport        506 non-null    object
#  13  Num_Hos_Beds   498 non-null    float64
#  14  Num_Hot_Rooms  506 non-null    int32
#  15  Waterbody      351 non-null    object
#  16  Rainfall       506 non-null    int64
# ...

# %% [markdown]
# ### Null value handling

# %%
df_House_Price_Data.head()
# Out:
#    Price  Crime_Rate  Resid_Area  Air_Qualitiy Room_num  Age  Dist1  Dist2  \
# 0   24.0     0.00632       32.31         0.538        6   65   4.35   3.81
# 1   21.6     0.02731       37.07         0.469        6   78   4.99   4.70
# 2   34.7     0.02729       37.07         0.469        7   61   5.03   4.86
# 3   33.4     0.03237       32.18         0.458        6   45   6.21   5.93
# 4   36.2     0.06905       32.18         0.458        7   54   6.16   5.86
#
#    Dist3  Dist4  Teachers  Poor_Prop Airport  Num_Hos_Beds  Num_Hot_Rooms  \
# 0   4.18   4.01        24       4.98     YES         5.480             11
# 1   5.12   5.06        22       9.14      NO         7.332             12
# 2   5.01   4.97        22       4.03      NO         7.394            101
# 3   6.16   5.96        21       2.94     YES         9.268             11
# 4   6.37   5.86        21       5.33      NO         8.824             11
#
#   Waterbody  Rainfall Bus_Ter     Parks
# ...

# %%
# find the number of missing value
df_House_Price_Data.isnull().sum()
# Out:
# Price              0
# Crime_Rate         0
# Resid_Area         0
# Air_Qualitiy       0
# Room_num           0
# Age                0
# Dist1              0
# Dist2              0
# Dist3              0
# Dist4              0
# Teachers           0
# Poor_Prop          0
# Airport            0
# Num_Hos_Beds       8
# Num_Hot_Rooms      0
# Waterbody        155
# Rainfall           0
# Bus_Ter            0
# Parks              0
# dtype: int64

# %%
df_House_Price_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          506 non-null    float64
#  1   Crime_Rate     506 non-null    float64
#  2   Resid_Area     506 non-null    float64
#  3   Air_Qualitiy   506 non-null    float64
#  4   Room_num       506 non-null    object
#  5   Age            506 non-null    int32
#  6   Dist1          506 non-null    float64
#  7   Dist2          506 non-null    float64
#  8   Dist3          506 non-null    float64
#  9   Dist4          506 non-null    float64
#  10  Teachers       506 non-null    int32
#  11  Poor_Prop      506 non-null    float64
#  12  Airport        506 non-null    object
#  13  Num_Hos_Beds   498 non-null    float64
#  14  Num_Hot_Rooms  506 non-null    int32
#  15  Waterbody      351 non-null    object
#  16  Rainfall       506 non-null    int64
# ...

# %%
# Laws
# When we have less than 10% data is missing remove the observation
# When we have missing percentge between 30-70% then we need to impute the missing value
# When we have more than 80% data is missing, remove the attribute

# %%
round(df_House_Price_Data.isnull().sum()/len(df_House_Price_Data)*100,2)
# Out:
# Price             0.00
# Crime_Rate        0.00
# Resid_Area        0.00
# Air_Qualitiy      0.00
# Room_num          0.00
# Age               0.00
# Dist1             0.00
# Dist2             0.00
# Dist3             0.00
# Dist4             0.00
# Teachers          0.00
# Poor_Prop         0.00
# Airport           0.00
# Num_Hos_Beds      1.58
# Num_Hot_Rooms     0.00
# Waterbody        30.63
# Rainfall          0.00
# Bus_Ter           0.00
# Parks             0.00
# dtype: float64

# %%
# Impute the missing value present in waterbody
# Find the mode of the column
df_House_Price_Data.Waterbody.mode()
# Out:
# 0    River
# Name: Waterbody, dtype: object

# %%
# Replace the null value in waterbody with the mode
df_House_Price_Data.Waterbody.fillna('River',inplace=True)
df_House_Price_Data.isnull().sum()
# Out:
# C:\Users\Hetvi\AppData\Local\Temp\ipykernel_11536\1061149307.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_House_Price_Data.Waterbody.fillna('River',inplace=True)
# Price            0
# Crime_Rate       0
# Resid_Area       0
# Air_Qualitiy     0
# Room_num         0
# Age              0
# Dist1            0
# Dist2            0
# Dist3            0
# Dist4            0
# Teachers         0
# Poor_Prop        0
# Airport          0
# Num_Hos_Beds     8
# Num_Hot_Rooms    0
# Waterbody        0
# ...

# %%
# We have less than 2% data missing from Num_Hos_Beds, Let`s remove the observation
df_House_Price_Data.dropna(inplace=True)

# %%
df_House_Price_Data.isnull().sum()
# Out:
# Price            0
# Crime_Rate       0
# Resid_Area       0
# Air_Qualitiy     0
# Room_num         0
# Age              0
# Dist1            0
# Dist2            0
# Dist3            0
# Dist4            0
# Teachers         0
# Poor_Prop        0
# Airport          0
# Num_Hos_Beds     0
# Num_Hot_Rooms    0
# Waterbody        0
# Rainfall         0
# Bus_Ter          0
# Parks            0
# dtype: int64

# %% [markdown]
# ### Outlier Detection and Treatment

# %%
df_House_Price_Data.plot(kind='box')
plt.xticks(rotation = 90)
plt.title('Outlier Detection')
plt.show()

# %%
df_House_Price_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 498 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          498 non-null    float64
#  1   Crime_Rate     498 non-null    float64
#  2   Resid_Area     498 non-null    float64
#  3   Air_Qualitiy   498 non-null    float64
#  4   Room_num       498 non-null    object
#  5   Age            498 non-null    int32
#  6   Dist1          498 non-null    float64
#  7   Dist2          498 non-null    float64
#  8   Dist3          498 non-null    float64
#  9   Dist4          498 non-null    float64
#  10  Teachers       498 non-null    int32
#  11  Poor_Prop      498 non-null    float64
#  12  Airport        498 non-null    object
#  13  Num_Hos_Beds   498 non-null    float64
#  14  Num_Hot_Rooms  498 non-null    int32
#  15  Waterbody      498 non-null    object
#  16  Rainfall       498 non-null    int64
# ...

# %%
df_num = df_House_Price_Data.select_dtypes(np.number)

# %% [markdown]
# #### Inter Quantile Range Method

# %%
q1 = df_num.quantile(0.25)
q3 = df_num.quantile(0.75)
iqr = q3-q1
df_num = df_num[(df_num >= q1-1.5*iqr) & (df_num <= q3+1.5*iqr)]

# %%
df_num= df_num.reset_index()

# %%
df_num.plot(kind='box')
plt.xticks(rotation = 90)
plt.show()

# %%
# Concate the treated dataframe with categorical dataframe
df_Cat = df_House_Price_Data.select_dtypes('object')

# %%
df_Cat= df_Cat.reset_index()

# %%
print(df_num.shape)
print(df_Cat.shape)
# Out:
# (498, 16)
# (498, 5)

# %%
# Concate both
df_House_Price_Data = pd.concat((df_num,df_Cat),axis=1)
df_House_Price_Data.shape
# Out:
# (498, 21)

# %%
# authenticity check
df_House_Price_Data.isnull().sum()
# Out:
# index             0
# Price            39
# Crime_Rate       64
# Resid_Area        0
# Air_Qualitiy      0
# Age               0
# Dist1             5
# Dist2             5
# Dist3             5
# Dist4             5
# Teachers         14
# Poor_Prop         7
# Num_Hos_Beds      0
# Num_Hot_Rooms     2
# Rainfall          0
# Parks             5
# index             0
# Room_num          0
# Airport           0
# Waterbody         0
# Bus_Ter           0
# dtype: int64

# %%
df_House_Price_Data.dropna(inplace=True)

# %%
df_House_Price_Data.isnull().sum()
# Out:
# index            0
# Price            0
# Crime_Rate       0
# Resid_Area       0
# Air_Qualitiy     0
# Age              0
# Dist1            0
# Dist2            0
# Dist3            0
# Dist4            0
# Teachers         0
# Poor_Prop        0
# Num_Hos_Beds     0
# Num_Hot_Rooms    0
# Rainfall         0
# Parks            0
# index            0
# Room_num         0
# Airport          0
# Waterbody        0
# Bus_Ter          0
# dtype: int64

# %%
# join of column then use concate and for rows use merge
df_House_Price_Data.shape
# Out:
# (376, 21)

# %% [markdown]
# # 3. Exploratory Data Analysis

# %%
# Univarite Analysis
# Bivariate Analysis
# Multi Variate Analysis

# %% [markdown]
# ### Univarite Analsis

# %%
# Let segregates the numerical columns and the categorical columns
df_num = df_House_Price_Data.select_dtypes(include=np.number)

# %%
df_num.head()
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Qualitiy  Age  Dist1  Dist2  \
# 0      0   24.0     0.00632       32.31         0.538   65   4.35   3.81
# 1      1   21.6     0.02731       37.07         0.469   78   4.99   4.70
# 3      3   33.4     0.03237       32.18         0.458   45   6.21   5.93
# 4      4   36.2     0.06905       32.18         0.458   54   6.16   5.86
# 5      5   28.7     0.02985       32.18         0.458   58   6.22   5.80
#
#    Dist3  Dist4  Teachers  Poor_Prop  Num_Hos_Beds  Num_Hot_Rooms  Rainfall  \
# 0   4.18   4.01      24.0       4.98         5.480           11.0        23
# 1   5.12   5.06      22.0       9.14         7.332           12.0        42
# 3   6.16   5.96      21.0       2.94         9.268           11.0        45
# 4   6.37   5.86      21.0       5.33         8.824           11.0        55
# 5   6.23   5.99      21.0       5.21         7.174           14.0        53
#
#       Parks  index
# 0  0.049347      0
# 1  0.046146      1
# ...

# %% [markdown]
# ### Univariate Analysis on Categorical Data

# %%
# Categorical Data Frame
df_Cat = df_House_Price_Data.select_dtypes(include=['object'])

# %%
df_Cat.head()
# Out:
#   Room_num Airport Waterbody Bus_Ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES
# 3        6     YES      Lake     YES
# 4        7      NO      Lake     YES
# 5        6     YES     River     YES

# %% [markdown]
# #### Room Number

# %%
# Find the count of each category present in that column
df_Cat.Room_num.value_counts()
# Out:
# Room_num
# 6    228
# 5    120
# 7     22
# 4      4
# 8      1
# 3      1
# Name: count, dtype: int64

# %%
# Visualize the Count
df_Cat.Room_num.value_counts().plot(kind = 'bar')
plt.xlabel('Room_num')
plt.show()

# %% [markdown]
# **Interpretation**
#  - We have imbalanced data in Room_num column.
#  - 6 is a Category who is dominating most, its count is 228.
#  - 3 is a Category having least number of observation, its count is 1.

# %%
df_Cat.head()
# Out:
#   Room_num Airport Waterbody Bus_Ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES
# 3        6     YES      Lake     YES
# 4        7      NO      Lake     YES
# 5        6     YES     River     YES

# %% [markdown]
# #### Airport

# %%
# Find the value counts for Airport column
df_Cat.Airport.value_counts()
# Out:
# Airport
# YES    205
# NO     171
# Name: count, dtype: int64

# %%
# Let`s Plot the Count
df_Cat.Airport.value_counts().plot(kind = 'bar', color='purple')
plt.xlabel('Airport')
plt.show()

# %% [markdown]
# **Interpretation**
#  - We have balanced data in this Airport Column.
#  - In the data there is 273 places where Airport is present and 225 places where Airport is not present.

# %%
df_Cat.head(2)
# Out:
#   Room_num Airport Waterbody Bus_Ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES

# %% [markdown]
# #### Waterbody

# %%
# Find the value counts of each category present in Waterbody column
df_Cat.Waterbody.value_counts()
# Out:
# Waterbody
# River             251
# Lake               70
# Lake and River     55
# Name: count, dtype: int64

# %%
# Visualize the Count
df_Cat.Waterbody.value_counts().plot(kind = 'bar', color='pink')
plt.title('Count of Waterbody')
plt.xlabel('Waterbody')
plt.ylabel('Counts')
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - Most of the places having a river as waterbody, its count is 178.
#  - There few places where lake and river are the waterbody, its count is 71.
#  - This data is imbalance.

# %%
# to balance data use oversampling or undersampling methods
# mostly used method: smot

# %%
df_Cat.head(2)
# Out:
#   Room_num Airport Waterbody Bus_Ter
# 0        6     YES     River     YES
# 1        6      NO      Lake     YES

# %% [markdown]
# #### Bus Terminals

# %%
# Find the value counts of each category present in Waterbody column
df_Cat.Bus_Ter.value_counts()
# Out:
# Bus_Ter
# YES    376
# Name: count, dtype: int64

# %%
# Visualize the Count
df_Cat.Bus_Ter.value_counts().plot(kind = 'bar')
plt.title('Count of Bus Terminals')
plt.xlabel('Bus Terminal')
plt.ylabel('Counts')
plt.xticks(rotation=360)
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - All  the places we have contain the bus terminal
#  - ACTION: Remove that column from the data

# %%
# Drop the column
df_House_Price_Data.drop('Bus_Ter',axis=1 , inplace = True)

# %%
df_House_Price_Data.shape
# Out:
# (376, 20)

# %%
df_House_Price_Data.shape[0]
# Out:
# 376

# %%
df_House_Price_Data.shape[1]
# Out:
# 20

# %% [markdown]
# ### Univariate Analysis on Numerical Data

# %%
df_num.head()
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Qualitiy  Age  Dist1  Dist2  \
# 0      0   24.0     0.00632       32.31         0.538   65   4.35   3.81
# 1      1   21.6     0.02731       37.07         0.469   78   4.99   4.70
# 3      3   33.4     0.03237       32.18         0.458   45   6.21   5.93
# 4      4   36.2     0.06905       32.18         0.458   54   6.16   5.86
# 5      5   28.7     0.02985       32.18         0.458   58   6.22   5.80
#
#    Dist3  Dist4  Teachers  Poor_Prop  Num_Hos_Beds  Num_Hot_Rooms  Rainfall  \
# 0   4.18   4.01      24.0       4.98         5.480           11.0        23
# 1   5.12   5.06      22.0       9.14         7.332           12.0        42
# 3   6.16   5.96      21.0       2.94         9.268           11.0        45
# 4   6.37   5.86      21.0       5.33         8.824           11.0        55
# 5   6.23   5.99      21.0       5.21         7.174           14.0        53
#
#       Parks  index
# 0  0.049347      0
# 1  0.046146      1
# ...

# %% [markdown]
# #### Price

# %%
df_num.Price.plot(kind = 'kde', color='red') 
plt.title('KDE plot of Price')
plt.grid()
plt.show()

# %%
# Find the minimum value
df_num.Price.min()
# Out:
# 7.0

# %%
# Find the maximum value
df_num.Price.max()
# Out:
# 36.4

# %%
# Find the average value
df_num.Price.mean()
# Out:
# 21.846808510638297

# %% [markdown]
# **Interpretation**
#  - This data is slightly normally distributed.
#  - The houses we have their prices lies between 8 lakhs to 40 lakhs
#  - The house we have with least price is 7 lakh.
#  - The house with maximum price is 50 lakhs.
#  - Average price is for houses is 22 lakh 57 thousands.

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Qualitiy  Age  Dist1  Dist2  \
# 0      0   24.0     0.00632       32.31         0.538   65   4.35   3.81
# 1      1   21.6     0.02731       37.07         0.469   78   4.99   4.70
#
#    Dist3  Dist4  Teachers  Poor_Prop  Num_Hos_Beds  Num_Hot_Rooms  Rainfall  \
# 0   4.18   4.01      24.0       4.98         5.480           11.0        23
# 1   5.12   5.06      22.0       9.14         7.332           12.0        42
#
#       Parks  index
# 0  0.049347      0
# 1  0.046146      1

# %% [markdown]
# #### Crime_Rate

# %%
# Find the minimum value
df_num.Crime_Rate.min()
# Out:
# 0.00632

# %%
# Find the maximum value
df_num.Crime_Rate.max()
# Out:
# 8.98296

# %%
# Find the average value
df_num.Crime_Rate.mean()
# Out:
# 1.2156331382978725

# %%
df_num.Crime_Rate.plot(kind = 'kde', color='purple') 
plt.title('KDE plot of Crime Rate')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The minimum crime rate is 0.00632.
#  - The maximum crime rate is 8.98296.
#  - The average crime rate is 1.21.
#  - Hence the crime rate is not normally distributed as the minimum value is 0.006 and maximum is 9

# %% [markdown]
# #### Residential  Area

# %%
# Find the minimum value
df_num.Resid_Area.min()
# Out:
# 30.74

# %%
# Find the maximum value
df_num.Resid_Area.max()
# Out:
# 57.74

# %%
# Find the average value
df_num.Resid_Area.mean()
# Out:
# 40.443617021276594

# %%
df_num.Resid_Area.plot(kind = 'kde', color='green') 
plt.title('KDE plot of Residential Area')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The minimum Residential Area is 30.46.
#  - The maximum Residential Area is 57.74.
#  - The average crime rate is 40.44.
#  - This is multimodel data.
#  - It lies between 30 to 45 for first model and 45 to 58 for second model.
#  - Hence the crime rate is not normally distributed.

# %% [markdown]
# #### Air Qualitiy

# %%
# Find the minimum value
df_num.Air_Qualitiy.min()
# Out:
# 0.385

# %%
# Find the maximum value
df_num.Air_Qualitiy.max()
# Out:
# 0.871

# %%
# Find the maximum value
df_num.Air_Qualitiy.mean()
# Out:
# 0.5334140957446809

# %%
df_num.Air_Qualitiy.plot(kind = 'kde', color='green') 
plt.title('KDE plot of Air Qualitiy')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - This data is not normally distributed as it has minimum value 0.3 and maximum value 0.8
#  - The minimum value of Air Quality is 0.385.
#  - The maximum value of Air Quality is 0.871.
#  - The Average Air Quality value is 0.533.

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Qualitiy  Age  Dist1  Dist2  \
# 0      0   24.0     0.00632       32.31         0.538   65   4.35   3.81
# 1      1   21.6     0.02731       37.07         0.469   78   4.99   4.70
#
#    Dist3  Dist4  Teachers  Poor_Prop  Num_Hos_Beds  Num_Hot_Rooms  Rainfall  \
# 0   4.18   4.01      24.0       4.98         5.480           11.0        23
# 1   5.12   5.06      22.0       9.14         7.332           12.0        42
#
#       Parks  index
# 0  0.049347      0
# 1  0.046146      1

# %% [markdown]
# #### Age

# %%
# Find the minimum value
df_num.Age.min()
# Out:
# 2

# %%
# Find the maximum value
df_num.Age.max()
# Out:
# 100

# %%
# Find the maximum value
df_num.Age.mean()
# Out:
# 63.922872340425535

# %%
df_num.Age.plot(kind = 'kde', color='orange') 
plt.title('KDE plot of Age')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The maximum Age is 100 and minimum age is 2.
#  - The Average Age is 63.92.
#  - This is not normally diatributed.
#  - It lies between 2 and 100.

# %% [markdown]
# #### Distance1

# %%
# Find the minimum value
df_num.Dist1.min()
# Out:
# 1.34

# %%
# Find the maximum value
df_num.Dist1.max()
# Out:
# 9.44

# %%
# Find the maximum value
df_num.Dist1.mean()
# Out:
# 4.3179521276595745

# %%
df_num.Dist1.plot(kind = 'kde', color='green') 
plt.title('KDE plot of Distance')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - This is slightly normally distributed.
#  - The minimum value of distance1 is 1.34.
#  - The maximum value of distance1 is 9.44.
#  - It lies between 0.3 and 10.

# %% [markdown]
# #### Distance2

# %%
# Find the minimum value
df_num.Dist2.min()
# Out:
# 1.04

# %%
# Find the maximum value
df_num.Dist2.max()
# Out:
# 9.11

# %%
# Find the maximum value
df_num.Dist2.mean()
# Out:
# 3.9738297872340427

# %%
df_num.Dist2.plot(kind = 'kde', color='blue') 
plt.title('KDE plot of Distance')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - This is slightly normally distributed.
#  - The minimum value of distance1 is 1.04.
#  - The maximum value of distance1 is 9.11.
#  - It lies between 0.3 and 10.
#  - Average value is 3.97.

# %%
# Find the minimum value
df_num.Dist3.min()
# Out:
# 1.55

# %%
# Find the maximum value
df_num.Dist3.max()
# Out:
# 9.48

# %%
# Find the maximum value
df_num.Dist3.mean()
# Out:
# 4.3096010638297875

# %%
df_num.Dist3.plot(kind = 'kde', color='green') 
plt.title('KDE plot of Distance')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - This is slightly normally distributed.
#  - The minimum value of distance1 is 1.55.
#  - The maximum value of distance1 is 9.48.
#  - It lies between 0.3 and 13.
#  - Average value is 4.309.

# %% [markdown]
# #### Teachers

# %%
# Find the minimum value
df_num.Teachers.min()
# Out:
# 18.0

# %%
# Find the maximum value
df_num.Teachers.max()
# Out:
# 25.0

# %%
# Find the maximum value
df_num.Teachers.mean()
# Out:
# 20.981382978723403

# %%
df_num.Teachers.plot(kind = 'kde', color='pink') 
plt.title('KDE plot of Teachers')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The maximum Teachers is 25 and minimum Teachers is 18.
#  - The Average Teachers is 20.98.
#  - This is not normally distributed.
#  - It lies between 18 and 27

# %%
df_num.head(2)
# Out:
#    index  Price  Crime_Rate  Resid_Area  Air_Qualitiy  Age  Dist1  Dist2  \
# 0      0   24.0     0.00632       32.31         0.538   65   4.35   3.81
# 1      1   21.6     0.02731       37.07         0.469   78   4.99   4.70
#
#    Dist3  Dist4  Teachers  Poor_Prop  Num_Hos_Beds  Num_Hot_Rooms  Rainfall  \
# 0   4.18   4.01      24.0       4.98         5.480           11.0        23
# 1   5.12   5.06      22.0       9.14         7.332           12.0        42
#
#       Parks  index
# 0  0.049347      0
# 1  0.046146      1

# %% [markdown]
# #### Poor Proportion

# %%
# Find the minimum value
df_num.Poor_Prop.min()
# Out:
# 1.98

# %%
# Find the maximum value
df_num.Poor_Prop.max()
# Out:
# 30.81

# %%
# Find the maximum value
df_num.Poor_Prop.mean()
# Out:
# 11.774973404255318

# %%
df_num.Poor_Prop.plot(kind = 'kde', color='green') 
plt.title('KDE plot of Poor Propotion')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The maximum poor propotion is 37.81 and minimum poor propotion is 1.98.
#  - The Average poor propotion is 11.77.
#  - This is slightly normally diatributed.
#  - It lies between 1 to 38.

# %% [markdown]
# #### Number of Hospital beds

# %%
# Find the minimum value
df_num.Num_Hos_Beds.min()
# Out:
# 5.268

# %%
# Find the maximum value
df_num.Num_Hos_Beds.max()
# Out:
# 10.668

# %%
# Find the maximum value
df_num.Num_Hos_Beds.mean()
# Out:
# 7.876297872340427

# %%
df_num.Num_Hos_Beds.plot(kind = 'kde', color='red') 
plt.title('KDE plot of Number of Hospital Beds')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The maximum Number of Hospital Beds is 10.668 and minimum Number of Hospital Beds is 5.268.
#  - The Average Number of Hospital Beds is 7.87.
#  - This is not normally diatributed.
#  - It lies between 5 and 12.

# %% [markdown]
# #### Number of Hotel Rooms

# %%
# Find the minimum value
df_num.Num_Hot_Rooms.min()
# Out:
# 10.0

# %%
# Find the maximum value
df_num.Num_Hot_Rooms.max()
# Out:
# 15.0

# %%
# Find the maximum value
df_num.Num_Hot_Rooms.mean()
# Out:
# 12.5

# %%
df_num.Num_Hot_Rooms.plot(kind = 'kde', color='purple') 
plt.title('KDE plot of Number of Hotels Rooms')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The maximum Number of Hotels Rooms is 15 and minimum Number of Hotels Rooms is 10.
#  - The Average Number of Hospital Beds is 12.5.
#  - This is not normally diatributed.
#  - It lies between 10 and 16.

# %% [markdown]
# #### Rainfall

# %%
# Find the maximum value
df_num.Rainfall.min()
# Out:
# 3

# %%
# Find the maximum value
df_num.Rainfall.max()
# Out:
# 60

# %%
# Find the maximum value
df_num.Rainfall.mean()
# Out:
# 38.598404255319146

# %%
df_num.Rainfall.plot(kind = 'kde', color='red') 
plt.title('KDE plot of Rainfall')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The maximum Rainfall is 60 and minimum Rainfall is 3.
#  - The Average Rainfall is 38.59.
#  - This is not normally diatributed.
#  - It lies between 10 and 60.

# %% [markdown]
# #### Parks

# %%
# Find the minimum value
df_num.Parks.min()
# Out:
# 0.033291762

# %%
# Find the maximum value
df_num.Parks.max()
# Out:
# 0.083032787

# %%
# Find the maximum value
df_num.Parks.mean()
# Out:
# 0.05268840343882978

# %%
df_num.Parks.plot(kind = 'kde', color='orange') 
plt.title('KDE plot of Parks')
plt.grid()
plt.show()

# %% [markdown]
# **Interpretation**
#  - The maximum park is 0.0867 and minimum park is 0.03.
#  - The Average park is 0.0526.
#  - This is slightly normally diatributed.
#  - It lies between 0.03 and 0.09.

# %% [markdown]
# ### Bivariate Analysis

# %%
# Step1: Do the Bivariate Analysis for Numerical Variables
# Find the Correlation
df_num.corr()
# Out:
#                   index     Price  Crime_Rate  Resid_Area  Air_Qualitiy  \
# index          1.000000 -0.130497    0.521741    0.326491      0.322834
# Price         -0.130497  1.000000   -0.424735   -0.539404     -0.518091
# Crime_Rate     0.521741 -0.424735    1.000000    0.554473      0.649419
# Resid_Area     0.326491 -0.539404    0.554473    1.000000      0.753000
# Air_Qualitiy   0.322834 -0.518091    0.649419    0.753000      1.000000
# Age            0.081943 -0.556358    0.418289    0.598148      0.688243
# Dist1         -0.228977  0.368112   -0.456078   -0.700206     -0.745603
# Dist2         -0.233908  0.365491   -0.455079   -0.703032     -0.747011
# Dist3         -0.236092  0.364496   -0.458358   -0.703908     -0.746911
# Dist4         -0.220572  0.366804   -0.447356   -0.702769     -0.742947
# Teachers      -0.261536  0.402793   -0.348126   -0.341594     -0.224335
# Poor_Prop      0.074148 -0.750503    0.393205    0.562430      0.539936
# ...

# %%
# Draw the heat map for correlation
sns.heatmap(df_num.corr(),annot= True)
sns.set(rc={"figure.figsize": (15, 15)})

# %% [markdown]
# #### Positive
#  - Parks-Resid_Area
#  - Parks-Crime_Rate
#  - Parks-Air_Quality
#  - Park-Age
#  - Park-Poor_Prop
#  - Poor_prop-Price
#  - Poor_Prop-Resid_Area
#  - Poor_Prop-Air_Quality
#  - Poor_Prop-Age
#  - Dist4-Dist1
#  - Dist4-Dist2
#  - Dist4-Dist3
#  - Dist3-Dist1
#  - Dist3-Dist2
#  - Dist2-Dist1
#  - Age-Air_Quality
#  - Air_Quaity-Resid_Area
#  - Age-Resid_Area
#  - Age-Air_Quality
#  - Air_Quality-Crime_Rate
#  - Resid_Area-Crime_Rate
#
#
# #### Negative
#  - Parks-Dist1
#  - Parks-Dist2
#  - Parks-Dist3
#  - Parks-Dist4
#  - Dist4-Resid_Area
#  - Dist4-Air_Qualitiy
#  - Dist4-Age
#  - Dist3-Resid_Area
#  - Dist3-Air_Qualitiy
#  - Dist3-Age
#  - Dist2-Resid_Area
#  - Dist2-Air_Qualitiy
#  - Dist2-Age
#  - Dist1-Resid_Area
#  - Dist1-Air_Qualitiy
#  - Dist1-Age
#  - Age-Price
#  - Resid_Area-Parks
#  - Air_Quality-Price

# %% [markdown]
# #### Parks-Residential Area

# %%
sns.scatterplot(x='Parks', y='Price',data=df_num)
plt.title('Correlation between Parks and Residential Area',fontsize=15)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Price and Parks.

# %% [markdown]
# #### Parks-Crime Rate

# %%
sns.scatterplot(x='Parks', y='Crime_Rate',data=df_num)
plt.title('Correlation between Parks and Crime Rate',fontsize=15)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - This is heteroscedasticity pattern,where most data points are concentrated near the origin and there is a spread of points with higher values

# %% [markdown]
# #### Parks-Air Quality

# %%
sns.scatterplot(x='Parks', y='Air_Qualitiy',data=df_num)
plt.title('Correlation between Parks and Air Quality',fontsize=15)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is Positive Linear correlation between Air Quality and Parks.
#  - We can see that as the number of parks increases, the air quality also improve.

# %% [markdown]
# #### Parks-Age

# %%
sns.scatterplot(x='Parks', y='Age',data=df_num)
plt.title('Correlation between Parks and Age',fontsize=15)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is slightly positive correlation between Age and Parks.
#  - As the Number of parks increases so the age is.

# %% [markdown]
# #### Park-Poor Propotion

# %%
sns.scatterplot(x='Parks', y='Poor_Prop',data=df_num)
plt.title('Correlation between Parks and Poor Propotion',fontsize=15)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Parks and Poor Proportion.

# %% [markdown]
# #### Poor_prop-Price

# %%
sns.scatterplot(x='Poor_Prop', y='Price',data=df_num)
plt.title('Correlation between Poor propotion and Price',fontsize=15)
plt.show()

# %% [markdown]
# **Interpretation**
#  - There is slightly negative correlation.
#  - We can say that if the Price of the house is high then Proportion of Poor Population is less.

# %% [markdown]
# #### Poor_Prop-Resid_Area

# %%
sns.scatterplot(x='Poor_Prop', y='Resid_Area',data=df_num)
plt.title('Correlation between Poor propotion and Residential Area',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - This is heteroscedasticity pattern,where most data points are concentrated near the origin and there is a spread of points with higher values

# %% [markdown]
#  #### Poor_Prop-Air_Quality

# %%
sns.scatterplot(x='Poor_Prop', y='Air_Qualitiy',data=df_num)
plt.title('Correlation between Poor propotion and Air Quality',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - This is heteroscedasticity pattern,where most data points are concentrated near the origin and there is a spread of points with higher values

# %% [markdown]
# #### Poor_Prop-Age

# %%
sns.scatterplot(x='Poor_Prop', y='Age',data=df_num)
plt.title('Correlation between Poor propotion and Age',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - This is heteroscedasticity pattern,where most data points are concentrated near the origin and there is a spread of points with higher values

# %% [markdown]
# #### Dist4-Dist1

# %%
sns.scatterplot(x='Dist4', y='Dist1',data=df_num)
plt.title('Correlation between Dist4 and Dist1',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is Strong Positive Linear correlation between distance from trhe employeement hub1 and distance from trhe employeement hub4.

# %% [markdown]
# #### Dist4-Dist2

# %%
sns.scatterplot(x='Dist4', y='Dist2',data=df_num)
plt.title('Correlation between Dist4 and Dist2',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is Strong Positive Linear correlation between distance from trhe employeement hub2 and distance from trhe employeement hub4.

# %% [markdown]
# ####  Dist4-Dist3

# %%
sns.scatterplot(x='Dist4', y='Dist3',data=df_num)
plt.title('Correlation between Dist4 and Dist3',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is Strong Positive Linear correlation between distance from trhe employeement hub3 and distance from trhe employeement hub4.

# %% [markdown]
# #### Dist3-Dist1

# %%
sns.scatterplot(x='Dist3', y='Dist1',data=df_num)
plt.title('Correlation between Dist3 and Dist1',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is Strong Positive Linear correlation between distance from trhe employeement hub1 and distance from trhe employeement hub3.

# %% [markdown]
# #### Dist3-Dist2

# %%
sns.scatterplot(x='Dist3', y='Dist2',data=df_num)
plt.title('Correlation between Dist3 and Dist2',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is very strong Positive Linear correlation between distance from trhe employeement hub2 and distance from trhe employeement hub3.

# %% [markdown]
# #### Dist2-Dist1

# %%
sns.scatterplot(x='Dist2', y='Dist1',data=df_num)
plt.title('Correlation between Dist2 and Dist1',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is very strong Positive Linear correlation between distance from trhe employeement hub1 and distance from trhe employeement hub2.

# %% [markdown]
# #### Age-Air_Quality

# %%
sns.scatterplot(x='Age', y='Air_Qualitiy',data=df_num)
plt.title('Correlation between Age and Air Quality',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - This is heteroscedasticity pattern,where most data points are concentrated near the origin and there is a spread of points with higher values

# %% [markdown]
# #### Air_Quaity-Resid_Area

# %%
sns.scatterplot(x='Air_Qualitiy', y='Resid_Area',data=df_num)
plt.title('Correlation between Air Quality and Residential Area',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Residential Resid_Area and Air_Quality.

# %% [markdown]
# #### Age-Air_Quality

# %%
sns.scatterplot(x='Age', y='Air_Qualitiy',data=df_num)
plt.title('Correlation between Age and Air Quality',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - This is heteroscedasticity pattern,where most data points are concentrated near the origin and there is a spread of points with higher values

# %% [markdown]
# #### Air_Quality-Crime_Rate

# %%
sns.scatterplot(x='Air_Qualitiy', y='Crime_Rate',data=df_num)
plt.title('Correlation between Air Quality and Crime Rate',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Crime Rate and Air Quality.

# %% [markdown]
# #### Resid_Area-Crime_Rate

# %%
sns.scatterplot(x='Resid_Area', y='Crime_Rate',data=df_num)
plt.title('Correlation between Residential Area and Crime Rate',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Residential Area and Crime Rate.

# %% [markdown]
# #### Parks-Dist1

# %%
sns.scatterplot(x='Parks', y='Dist1',data=df_num)
plt.title('Correlation between Parks and Dist1',fontsize=15)
plt.show()

# %% [markdown]
# **Interpretation**
#  - There is negative correlation between distance from the employeement hub1 and Parks.
#  - We can say that if the Parks is high then the distance from the employeement hub1 is lesser.

# %% [markdown]
# #### Parks-Dist2

# %%
sns.scatterplot(x='Parks', y='Dist2',data=df_num)
plt.title('Correlation between Parks and Dist2',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is negative correlation between distance from the employment hub2 and Parks.

# %% [markdown]
# #### Parks-Dist3

# %%
sns.scatterplot(x='Parks', y='Dist3',data=df_num)
plt.title('Correlation between Parks and Dist3',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is negative correlation between distance from the employment hub3 and Parks.

# %% [markdown]
# #### Parks-Dist4

# %%
sns.scatterplot(x='Parks', y='Dist4',data=df_num)
sns.set(rc={"figure.figsize": (5, 5)})
plt.title('Correlation between Parks and Dist4',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is negative correlation between distance from the employment hub4 and Parks.

# %% [markdown]
# #### Dist3-Age

# %%
sns.scatterplot(x='Dist3', y='Age',data=df_num)
plt.title('Correlation between Dist3 and Age',fontsize=15)
plt.show()

# %% [markdown]
# **Interpretation**
#  - There is slightly negative correlation.
#  - We can say that if the age of the house is high than the distance from trhe employeement hub3 is lesser

# %% [markdown]
# #### Dist4-Resid_Area

# %%
sns.scatterplot(x='Dist4', y='Resid_Area',data=df_num)
plt.title('Correlation between Dist4 and Resid_Area',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is negative correlation between distance from the employment hub4 and Residential Area.

# %% [markdown]
# #### Dist4-Air_Qualitiy

# %%
sns.scatterplot(x='Dist4', y='Air_Qualitiy',data=df_num)
plt.title('Correlation between Dist4 and Air Quality',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is negative correlation between distance from the employment hub4 and Air Quality.

# %% [markdown]
# #### Dist4-Age

# %%
sns.scatterplot(x='Dist4', y='Age',data=df_num)
plt.title('Correlation between Dist4 and Age',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Distance from the Employment Hub4 and Age.

# %% [markdown]
# #### Dist3-Resid_Area

# %%
sns.scatterplot(x='Dist3', y='Resid_Area',data=df_num)
plt.title('Correlation between Dist3 and Residential Area',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Distance from the Employment Hub3 and Residential Area.

# %% [markdown]
# #### Dist3-Air_Qualitiy

# %%
sns.scatterplot(x='Dist3', y='Air_Qualitiy',data=df_num)
plt.title('Correlation between Dist3 and Air Quality',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is negative correlation between Distance from the Employment Hub3 and Air Quality.

# %% [markdown]
# #### Dist3-Age

# %%
sns.scatterplot(x='Dist3', y='Age',data=df_num)
plt.title('Correlation between Dist3 and Age',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Distance from the Employment Hub3 and Age.

# %% [markdown]
# #### Dist2-Resid_Area

# %%
sns.scatterplot(x='Dist2', y='Resid_Area',data=df_num)
plt.title('Correlation between Dist2 and Residential Area',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Distance from the Employment Hub2 and Residential Area.

# %% [markdown]
# #### Dist2-Air_Qualitiy

# %%
sns.scatterplot(x='Dist2', y='Air_Qualitiy',data=df_num)
plt.title('Correlation between Dist2 and Air Quality',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is negative relation between Distance from the Employment Hub2 and Air Quality.

# %% [markdown]
# #### Dist2-Age

# %%
sns.scatterplot(x='Dist2', y='Age',data=df_num)
plt.title('Correlation between Dist2 and Age',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is slightly negative relation between Distance from the Employment Hub2 and Age.

# %% [markdown]
# #### Dist1-Resid_Area

# %%
sns.scatterplot(x='Dist1', y='Resid_Area',data=df_num)
plt.title('Correlation between Dist1 and Residential Area',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is slightly negative relation between Distance from the Employment Hub1 and Residential Area.

# %% [markdown]
# #### Dist1-Air_Qualitiy

# %%
sns.scatterplot(x='Dist1', y='Air_Qualitiy',data=df_num)
plt.title('Correlation between Dist1 and Air Quality',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is negative relation between Distance from the Employment Hub1 and Air Quality.

# %% [markdown]
# #### Dist1-Age

# %%
sns.scatterplot(x='Dist1', y='Age',data=df_num)
plt.title('Correlation between Dist1 and Age',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Distance from the Employment Hub1 and Age.

# %% [markdown]
# #### Age-Price

# %%
sns.scatterplot(x='Age', y='Price',data=df_num)
plt.title('Correlation between Age and Price',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is homoscedasticity pattern between Price of the House and Age.

# %% [markdown]
# #### Resid_Area-Parks

# %%
sns.scatterplot(x='Resid_Area', y='Parks',data=df_num)
plt.title('Correlation between Residential Area and Parks',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - •	There is no relation between Residential Area and Parks.

# %% [markdown]
# #### Air_Quality-Price

# %%
sns.scatterplot(x='Air_Qualitiy', y='Price',data=df_num)
plt.title('Correlation between Air Quality and Price',fontsize=15)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - There is no relation between Price of the House and Air Quality.

# %%
# Parks
# Poor_prop
# Air_Quality
# Price

# %%
df_Cat.info(),df_House_Price_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 376 entries, 0 to 497
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Room_num   376 non-null    object
#  1   Airport    376 non-null    object
#  2   Waterbody  376 non-null    object
#  3   Bus_Ter    376 non-null    object
# dtypes: object(4)
# memory usage: 14.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 376 entries, 0 to 497
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          376 non-null    int64
#  1   Price          376 non-null    float64
#  2   Crime_Rate     376 non-null    float64
#  3   Resid_Area     376 non-null    float64
#  4   Air_Qualitiy   376 non-null    float64
#  5   Age            376 non-null    int32
#  6   Dist1          376 non-null    float64
#  7   Dist2          376 non-null    float64
#  8   Dist3          376 non-null    float64
# ...

# %%
# Visualize Categorical and Numerical data together.

# %%
sns.barplot(x='Room_num',y='Parks',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - Average Number of parks are high then numbers of rooms are 4.
#   - Average number of parks is lesser then numbers of rooms is 7.

# %%
sns.barplot(x='Room_num',y='Poor_Prop',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (7,7)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - When the propotion of poor population is high, the houses is over there we have 4 numbers of rooms.
#   - When we have 8 numbers of rooms in the house, the propotion of poor population is low.

# %%
sns.barplot(x='Room_num',y='Air_Qualitiy',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **Interpretation**
#  - When we have best air quality in the area, that time the average room number is 4 in the house.
#  - When we have the bad air quality in the area that time the average room number is 7 in the house.

# %%
sns.barplot(x='Room_num',y='Price',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - When numbers of rooms are 4 then the price is lowest.
#   - When the numbers of rooms is 7 then price is always high.

# %%
sns.barplot(x='Airport',y='Parks',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - Nothing Special to observe.

# %%
sns.barplot(x='Airport',y='Poor_Prop',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - Nothing Special to observe.

# %%
sns.barplot(x='Airport',y='Air_Qualitiy',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - Nothing Special to observe.

# %%
sns.barplot(x='Airport',y='Price',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - Nothing Special to observe.

# %%
sns.barplot(x='Waterbody',y='Parks',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - Nothing Special to observe.

# %%
sns.barplot(x='Waterbody',y='Poor_Prop',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5, 5)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - Nothing Special to observe.

# %%
sns.barplot(x='Waterbody',y='Air_Qualitiy',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5,5)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - Nothing Special to observe.

# %%
sns.barplot(x='Waterbody',y='Price',data=df_House_Price_Data)
sns.set(rc={"figure.figsize": (5,5)})
plt.show()

# %% [markdown]
# **Interpretation**
#   - Nothing Special to observe.

# %% [markdown]
# ### Multivariate Analysis

# %%
# Add Hue(Hue always be Categorical column)
# Cross tab
# Pivot Table

# %%
# data.gov

# %%
# Room_num-Parks
# Room_num-Air_Qualitiy
# Room_num-Poor_prop
# Room_num-Price
# Airport-Park
# Airport-Air_Qualitiy
# Airport-Poor_prop
# Airport-Price
# Waterbody-Park
# Waterbody-Air_Qualitiy
# Waterbody-Poor_prop
# Waterbody-Price

# %%
# Pairs: 2 Numerical columns(1 is always price-Target variable) 1 categorical

# Col1: Price,  col2:Parks,        col3:Room_num
# Col1: Price,  col2:Air_Quality,  col3:Room_num
# Col1: Price,  col2:Poor_Prop,    col3:Room_num

# Col1: Price,  col2:Parks,        col3:Airport
# Col1: Price,  col2:Air_Quality,  col3:Airport
# Col1: Price,  col2:Poor_Prop,    col3:Airport

# Col1: Price,  col2:Parks,        col3:Waterbody
# Col1: Price,  col2:Air_Quality,  col3:Waterbody
# Col1: Price,  col2:Poor_Prop,    col3:Waterbody

#Note: My column 3 should be the Hue parameter

# %%
df_House_Price_Data.columns
# Out:
# Index(['index', 'Price', 'Crime_Rate', 'Resid_Area', 'Air_Qualitiy', 'Age',
#        'Dist1', 'Dist2', 'Dist3', 'Dist4', 'Teachers', 'Poor_Prop',
#        'Num_Hos_Beds', 'Num_Hot_Rooms', 'Rainfall', 'Parks', 'index',
#        'Room_num', 'Airport', 'Waterbody'],
#       dtype='object')

# %% [markdown]
# #### Col1: Price,  Col2:Parks,  Col3:Room_num

# %%
# Scatter plot
sns.scatterplot(x='Price',y='Parks',hue='Room_num',data=df_House_Price_Data)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - When the number of Parks is High(0.08) that time Price is low (13 lacs), The average Number of Rooms in that senario is 3.
#  - When the number of Parks is low(0.04) that time Price is high (36 lacs), In that senario we have the average Number of Rooms is 8.

# %% [markdown]
# #### Col1: Price,  col2:Air_Quality,  col3:Room_num

# %%
# Scatter plot
sns.scatterplot(x='Price',y='Air_Qualitiy',hue='Room_num',data=df_House_Price_Data)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - When the Price of the house is low (11 lacs),that time Air Quality is really good(0.9), The average Number of Rooms in that senario is 4.
#  - When the Price of the house is high (36 lacs),that time Air Quality is really bad(0.45), The average Number of Rooms in that senario is 8.

# %% [markdown]
# #### Col1: Price,  col2:Poor_Prop,    col3:Room_num

# %%
# Scatter plot
sns.scatterplot(x='Price',y='Poor_Prop',hue='Room_num',data=df_House_Price_Data)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - When the Price of the house is low (7 lacs),that time propotion of poor population is so high(30), The average Number of Rooms in that senario is 5.
#  - When the Price of the house is high (36 lacs),that time propotion of poor population is low(3), The average Number of Rooms in that senario is 7.

# %% [markdown]
# #### Col1: Price,  col2:Parks,        col3:Airport

# %%
# Scatter plot
sns.scatterplot(x='Price',y='Parks',hue='Airport',data=df_House_Price_Data)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - When the Price of the house is low (12 lacs),that time number of Parks is very good(0.08), In that senario the Airport is present.
#  - When the Price of the house is high (37 lacs),that time number of Parks is very bad(0.045), In that senario the Airport is present.

# %% [markdown]
# #### Col1: Price,  col2:Air_Quality,  col3:Airport

# %%
# Scatter plot
sns.scatterplot(x='Price',y='Air_Qualitiy',hue='Airport',data=df_House_Price_Data)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - When the Price of the house is low (12 lacs),that time Air Quality is very good(0.09), In that senario the Airport is present.
#  - When the Price of the house is high (37 lacs),that time Air Quality is bad(0.045), In that senario the Airport is present.

# %% [markdown]
# #### Col1: Price,  col2:Poor_Prop,    col3:Airport

# %%
# Scatter plot
sns.scatterplot(x='Price',y='Poor_Prop',hue='Airport',data=df_House_Price_Data)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - When the Price of the house is low (5 lacs),that time propotion of poor population is high(29), In that senario the Airport is present.
#  - When the Price of the house is high (37 lacs),that time propotion of poor population is low(3), In that senario the Airport is present.

# %% [markdown]
# #### Col1: Price,  col2:Parks,        col3:Waterbody

# %%
# Scatter plot
sns.scatterplot(x='Price',y='Parks',hue='Waterbody',data=df_House_Price_Data)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - When the Price of the house is low (6 lacs),that time number of Parks is average(0.065), In that senario the Waterbody is there as River and Lake.
#  - When the Price of the house is high (37 lacs),that time number of Parks is low(0.05), In that senario the Waterbody is there as Lake.

# %% [markdown]
# #### Col1: Price,  col2:Air_Quality,  col3:Waterbody

# %%
# Scatter plot
sns.scatterplot(x='Price',y='Air_Qualitiy',hue='Waterbody',data=df_House_Price_Data)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - When the Price of the house is low (6 lacs),that time Air Quality is average(0.6), In that senario the Waterbody is there as River and Lake.
#  - When the Price of the house is high (36 lacs),that time Air Quality is low(0.45), In that senario the Waterbody is there as Lake.

# %% [markdown]
# #### Col1: Price,  col2:Poor_Prop,    col3:Waterbody

# %%
# Scatter plot
sns.scatterplot(x='Price',y='Poor_Prop',hue='Waterbody',data=df_House_Price_Data)
plt.show()

# %% [markdown]
# **_Interpretation_**
#  - When the Price of the house is low (12 lacs),that time propotion of Poor Population is high(29), In that senario the Waterbody is there as River.
#  - When the Price of the house is high (37 lacs),that time propotion of poor population is low(3), In that senario the Waterbody is there as River.

# %%
# Cross tab
# Pivot Table
# for these 2, we must have 2 categorical column and 1 numerical column(target vaiable)
# bcz we have so many numerical columns and we cant do these on each so take target column.

# %% [markdown]
# #### Arrangement for Pivot and Cross Tab

# %%
# Room_num-Parks
# Room_num-Air_Qualitiy
# Room_num-Poor_prop
# Room_num-Price
# Airport-Park
# Airport-Air_Qualitiy
# Airport-Poor_prop
# Airport-Price
# Waterbody-Park
# Waterbody-Air_Qualitiy
# Waterbody-Poor_prop
# Waterbody-Price

# %%
# Col1: Room_num, Col2: Airport, Col3: Price
# Col1: Room_num, Col2: Waterbody, Col3: Price
# Col1: Waterbody, Col2: Airport, Col3: Price

# %%
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 376 entries, 0 to 497
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          376 non-null    int64
#  1   Price          376 non-null    float64
#  2   Crime_Rate     376 non-null    float64
#  3   Resid_Area     376 non-null    float64
#  4   Air_Qualitiy   376 non-null    float64
#  5   Age            376 non-null    int32
#  6   Dist1          376 non-null    float64
#  7   Dist2          376 non-null    float64
#  8   Dist3          376 non-null    float64
#  9   Dist4          376 non-null    float64
#  10  Teachers       376 non-null    float64
#  11  Poor_Prop      376 non-null    float64
#  12  Num_Hos_Beds   376 non-null    float64
#  13  Num_Hot_Rooms  376 non-null    float64
#  14  Rainfall       376 non-null    int64
#  15  Parks          376 non-null    float64
#  16  index          376 non-null    int64
# ...

# %%
df_House_Price_Data.columns
# Out:
# Index(['index', 'Price', 'Crime_Rate', 'Resid_Area', 'Air_Qualitiy', 'Age',
#        'Dist1', 'Dist2', 'Dist3', 'Dist4', 'Teachers', 'Poor_Prop',
#        'Num_Hos_Beds', 'Num_Hot_Rooms', 'Rainfall', 'Parks', 'index',
#        'Room_num', 'Airport', 'Waterbody'],
#       dtype='object')

# %% [markdown]
# #### Cross Tab

# %% [markdown]
# #### Col1: Room_num, Col2: Airport, Col3: Price

# %%
pd.crosstab(df_House_Price_Data.Room_num,
            df_House_Price_Data.Airport,
            values= df_House_Price_Data.Price,
            aggfunc='mean')
# Out:
# Airport          NO        YES
# Room_num
# 3               NaN  27.500000
# 4         17.533333  11.800000
# 5         17.485000  19.328333
# 6         22.522449  22.969231
# 7         31.855556  31.684615
# 8         21.900000        NaN

# %% [markdown]
# #### Col1: Room_num, Col2: Waterbody, Col3: Price

# %%
pd.crosstab(df_House_Price_Data.Room_num,
            df_House_Price_Data.Waterbody,
            values= df_House_Price_Data.Price,
            aggfunc='mean')
# Out:
# Waterbody       Lake  Lake and River      River
# Room_num
# 3                NaN             NaN  27.500000
# 4          21.900000             NaN  14.166667
# 5          18.383333       18.200000  18.461538
# 6          22.871795       22.057143  22.916883
# 7          32.116667       32.600000  31.478571
# 8                NaN             NaN  21.900000

# %%
# Analysis always done on static data

# %% [markdown]
# ### Pivot Tab

# %% [markdown]
# #### Col1: Waterbody, Col2: Airport, Col3: Price

# %%
pd.pivot_table(data=df_House_Price_Data,
            index='Airport',
            columns='Waterbody',
            values= 'Price',
            aggfunc='mean')
# Out:
# Waterbody       Lake  Lake and River      River
# Airport
# NO         21.385714       20.003226  21.416071
# YES        22.595238       22.695833  22.325180
